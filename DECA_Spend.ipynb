# %% [markdown]
# <a href="https://colab.research.google.com/github/parraperez/Decam/blob/main/DECA_Spend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Revisión de Spend

# %%
# !pip install pandas
# !pip install xlrd
# !pip install psycopg2

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-783c367c-df7c-4b4d-bf5e-58bcb26fb707" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-783c367c-df7c-4b4d-bf5e-58bcb26fb707">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Spend 2021-2020.xlsx to Spend 2021-2020.xlsx

# %%
import io
df = pd.read_excel(io.BytesIO(uploaded["Spend 2021-2020.xlsx"]))
df.head(3)
# Out:
#   PAIS       BASE MONEDA      FECHA CODIGO ARTICULO DESCRIPCIÓN ARTICULO  \
# 0  ECU  Centinela    USD 2020-01-02      001FYVA002                  AJI
# 1  ECU  Centinela    USD 2020-01-02      001FYVA003             AGUACATE
# 2  ECU  Centinela    USD 2020-01-02      001FYVA004           AJO PELADO
#
#                        CLASE           SUBCLASE    TIPO      GRUPO  ...  \
# 0  INVENTARIO DE COMESTIBLES  FRUTAS Y VERDURAS  BIENES  ALIMENTOS  ...
# 1  INVENTARIO DE COMESTIBLES  FRUTAS Y VERDURAS  BIENES  ALIMENTOS  ...
# 2  INVENTARIO DE COMESTIBLES  FRUTAS Y VERDURAS  BIENES  ALIMENTOS  ...
#
#       LINEA UNIDAD MEDIDA CANTIDAD  VALOR UNITARIO  VALOR TOTAL  \
# 0  VERDURAS            KG      2.0            1.58         3.16
# 1  VERDURAS            KG      5.0            2.20        11.00
# 2  VERDURAS            KG      2.0            3.20         6.40
#
#    VALOR TOTAL USD                RAZÓN SOCIAL   DEPARTAMENTO  \
# ...

# %%
print(df.size)
df.isna().sum().sum()
# Out:
# 15997569
# 1447279

# %%
valor = df[df["RAZÓN SOCIAL"].str.contains("GUILLE",na=False)]
valor
# Out:
#        PAIS        BASE MONEDA      FECHA CODIGO ARTICULO  \
# 0       ECU   Centinela    USD 2020-01-02      001FYVA002
# 1       ECU   Centinela    USD 2020-01-02      001FYVA003
# 2       ECU   Centinela    USD 2020-01-02      001FYVA004
# 3       ECU   Centinela    USD 2020-01-02      001FYVB005
# 4       ECU   Centinela    USD 2020-01-02      001FYVC004
# ...     ...         ...    ...        ...             ...
# 752456  ECU  MontegoBay    USD 2021-10-28      001FYVN005
# 752457  ECU  MontegoBay    USD 2021-10-28      001FYVP020
# 757500  ECU   Centinela    USD 2021-09-13             NaN
# 757501  ECU   Centinela    USD 2021-09-13             NaN
# 758045  ECU   Centinela    USD 2021-10-27             NaN
#
#                                  DESCRIPCIÓN ARTICULO  \
# 0                                                 AJI
# 1                                            AGUACATE
# 2                                          AJO PELADO
# ...

# %%
from google.colab import files
Movimiento = df[df["RAZÓN SOCIAL"].str.contains("SERVICIOS POSTALES",na=False)]
Movimiento.to_excel("consulta.xlsx")
files.download("consulta.xlsx")

# %%
# !git clone https://github.com/parraperez/Decam.git
# Out:
# Cloning into 'Decam'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !git remote add origin https://github.com/parraperez/Decam.git
# !git push github master
# Out:
# fatal: remote origin already exists.
# error: src refspec master does not match any.
# error: failed to push some refs to 'github'

# %%
# !git init
# !git add README
# !git config --global user.email "parraperez@gmail.com"
# !git remote add google \  https://github.com/parraperez/Decam.git
# !git commit -m "primer envio"
# !git remote add origin /content/drive/MyDrive/Colab Notebooks/Deca/DECA-Spend.ipynb
# !git push origin master

# %%
# !git remote set-url --add origin ~/content/drive/MyDrive/Colab Notebooks/Deca/DECA-Spend.ipynb
# !git remote -v
# !git push origin main
# Out:
# usage: git remote set-url [--push] <name> <newurl> [<oldurl>]
#    or: git remote set-url --add <name> <newurl>
#    or: git remote set-url --delete <name> <url>
#
#     --push                manipulate push URLs
#     --add                 add URL
#     --delete              delete URLs
#
# origin	https://github.com/parraperez/Decam.git (fetch)
# origin	https://github.com/parraperez/Decam.git (push)
# error: src refspec main does not match any.
# error: failed to push some refs to 'https://github.com/parraperez/Decam.git'
